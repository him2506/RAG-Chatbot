# %% [markdown]
# # #**Generative-AI-RAG-app:**
# #### **Elevating Customer Support with AI-driven RAG application**

# %% [markdown]
# <img src='https://drive.google.com/uc?id=12NLHYlnV2pl8k7QRn9Fw8d4dyXjO1qZr'>

# %% [markdown]
# **The main objective of this application is to develop an interactive, retrieval-augmented application designed to provide generalized responses to queries, based on historical chat interactions between the user and the agent.**

# %% [markdown]
# **Provide the CSV file path**

# %%
import os
os.environ['ASSESSMENT_CSV_PATH'] = '/content/support_chat.csv'

# %% [markdown]
# ### **Install dependencies**

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117 --upgrade
# !pip install langchain einops accelerate transformers bitsandbytes scipy
# !pip install xformers sentencepiece
# !pip -q install chromadb
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch
# Requirement already satisfied: langchain in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (0.1.16)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
# Collecting transformers
#   Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
# Requirement already satisfied: scipy in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (1.4.32)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (0.0.33)
# Requirement already satisfied: requests<3,>=2 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (2.27.1)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (0.1.44)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (0.1.48)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (4.0.1)
# Requirement already satisfied: numpy<2,>=1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (1.21.5)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (2.7.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from accelerate) (23.2)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.3-cp39-none-win32.whl (282 kB)
# Requirement already satisfied: psutil in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from accelerate) (5.8.0)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
# Collecting accelerate
#   Downloading accelerate-0.29.2-py3-none-any.whl (297 kB)
#   Downloading accelerate-0.29.1-py3-none-any.whl (297 kB)
#   Downloading accelerate-0.29.0-py3-none-any.whl (297 kB)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#   Downloading accelerate-0.27.1-py3-none-any.whl (279 kB)
#   Downloading accelerate-0.27.0-py3-none-any.whl (279 kB)
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#   Downloading accelerate-0.26.0-py3-none-any.whl (270 kB)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#   Downloading accelerate-0.24.0-py3-none-any.whl (260 kB)
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#   Downloading accelerate-0.22.0-py3-none-any.whl (251 kB)
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#   Downloading accelerate-0.20.2-py3-none-any.whl (227 kB)
#   Downloading accelerate-0.20.1-py3-none-any.whl (227 kB)
#   Downloading accelerate-0.20.0-py3-none-any.whl (227 kB)
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#   Downloading accelerate-0.17.1-py3-none-any.whl (212 kB)
#   Downloading accelerate-0.17.0-py3-none-any.whl (212 kB)
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#   Downloading accelerate-0.15.0-py3-none-any.whl (191 kB)
#   Downloading accelerate-0.14.0-py3-none-any.whl (175 kB)
#   Downloading accelerate-0.13.2-py3-none-any.whl (148 kB)
#   Downloading accelerate-0.13.1-py3-none-any.whl (148 kB)
#   Downloading accelerate-0.13.0-py3-none-any.whl (148 kB)
#   Downloading accelerate-0.12.0-py3-none-any.whl (143 kB)
#   Downloading accelerate-0.11.0-py3-none-any.whl (123 kB)
#   Downloading accelerate-0.10.0-py3-none-any.whl (117 kB)
#   Downloading accelerate-0.9.0-py3-none-any.whl (106 kB)
#   Downloading accelerate-0.8.0-py3-none-any.whl (114 kB)
#   Downloading accelerate-0.7.1-py3-none-any.whl (79 kB)
#   Downloading accelerate-0.7.0-py3-none-any.whl (79 kB)
#   Downloading accelerate-0.6.2-py3-none-any.whl (65 kB)
#   Downloading accelerate-0.6.1-py3-none-any.whl (65 kB)
#   Downloading accelerate-0.6.0-py3-none-any.whl (65 kB)
#   Downloading accelerate-0.5.1-py3-none-any.whl (58 kB)
#   Downloading accelerate-0.5.0-py3-none-any.whl (57 kB)
#   Downloading accelerate-0.4.0-py3-none-any.whl (55 kB)
#   Downloading accelerate-0.3.0-py3-none-any.whl (49 kB)
#   Downloading accelerate-0.2.1-py3-none-any.whl (47 kB)
#   Downloading accelerate-0.2.0-py3-none-any.whl (47 kB)
#   Downloading accelerate-0.1.0-py3-none-any.whl (34 kB)
#   Downloading accelerate-0.0.1-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: filelock in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Collecting tokenizers<0.20,>=0.19
#   Using cached tokenizers-0.19.1-cp39-none-win32.whl (2.0 MB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from async-timeout<5.0.0,>=4.0.0->langchain) (4.11.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.1)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: colorama in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Installing collected packages: fsspec, huggingface-hub, tokenizers, safetensors, transformers, einops, bitsandbytes, accelerate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.3.0
#     Uninstalling fsspec-2022.3.0:
#       Successfully uninstalled fsspec-2022.3.0
# Successfully installed accelerate-0.0.1 bitsandbytes-0.42.0 einops-0.7.0 fsspec-2024.3.1 huggingface-hub-0.22.2 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.40.0
# Collecting xformers
#   Downloading xformers-0.0.25.post1.tar.gz (4.1 MB)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\himanchal.a.singh\\AppData\\Local\\Temp\\pip-install-asgfr28v\\xformers_b538d03f08324d8094cf459b26882364\\third_party/flash-attention/csrc/cutlass/examples/44_multi_gemm_ir_and_codegen/fixed_impl/epilogue/threadblock/default_thread_map_tensor_op_for_fused_bias.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\himanchal.a.singh\Anaconda3\python.exe' 'C:\Users\himanchal.a.singh\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\HIMANC~1.SIN\AppData\Local\Temp\tmpvwdv6l10'
#        cwd: C:\Users\himanchal.a.singh\AppData\Local\Temp\pip-install-t81v27_x\duckdb_1ca8f4c041f1443189105a23729d48c9
#   Complete output (80 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win32-cpython-39
#   creating build\lib.win32-cpython-39\duckdb
#   copying duckdb\bytes_io_wrapper.py -> build\lib.win32-cpython-39\duckdb
#   copying duckdb\filesystem.py -> build\lib.win32-cpython-39\duckdb
#   copying duckdb\udf.py -> build\lib.win32-cpython-39\duckdb
#   copying duckdb\__init__.py -> build\lib.win32-cpython-39\duckdb
#   creating build\lib.win32-cpython-39\duckdb\typing
#   copying duckdb\typing\__init__.py -> build\lib.win32-cpython-39\duckdb\typing
#   creating build\lib.win32-cpython-39\duckdb\query_graph
#   copying duckdb\query_graph\__main__.py -> build\lib.win32-cpython-39\duckdb\query_graph
#   creating build\lib.win32-cpython-39\duckdb\functional
#   copying duckdb\functional\__init__.py -> build\lib.win32-cpython-39\duckdb\functional
#   creating build\lib.win32-cpython-39\duckdb\value
#   copying duckdb\value\constant.py -> build\lib.win32-cpython-39\duckdb\value
#   creating build\lib.win32-cpython-39\adbc_driver_duckdb
#   copying adbc_driver_duckdb\dbapi.py -> build\lib.win32-cpython-39\adbc_driver_duckdb
#   copying adbc_driver_duckdb\__init__.py -> build\lib.win32-cpython-39\adbc_driver_duckdb
#   creating build\lib.win32-cpython-39\duckdb\experimental
#   copying duckdb\experimental\__init__.py -> build\lib.win32-cpython-39\duckdb\experimental
#   creating build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\conf.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\context.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\exception.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\_globals.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\_typing.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   copying duckdb\experimental\spark\__init__.py -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   creating build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\catalog.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\column.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\conf.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\dataframe.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\functions.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\group.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\readwriter.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\session.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\streaming.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\types.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\type_utils.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\udf.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\_typing.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   copying duckdb\experimental\spark\sql\__init__.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\sql
#   creating build\lib.win32-cpython-39\duckdb\experimental\spark\errors
#   copying duckdb\experimental\spark\errors\error_classes.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\errors
#   copying duckdb\experimental\spark\errors\utils.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\errors
#   copying duckdb\experimental\spark\errors\__init__.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\errors
#   creating build\lib.win32-cpython-39\duckdb\experimental\spark\errors\exceptions
#   copying duckdb\experimental\spark\errors\exceptions\base.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\errors\exceptions
#   copying duckdb\experimental\spark\errors\exceptions\__init__.py -> build\lib.win32-cpython-39\duckdb\experimental\spark\errors\exceptions
#   running egg_info
#   writing duckdb.egg-info\PKG-INFO
#   writing dependency_links to duckdb.egg-info\dependency_links.txt
#   writing top-level names to duckdb.egg-info\top_level.txt
#   ERROR setuptools_scm._file_finders.git listing git files failed - pretending there aren't any
#   reading manifest file 'duckdb.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.h' under directory 'duckdb'
#   warning: no files found matching '*.hpp' under directory 'duckdb'
#   warning: no files found matching '*.cpp' under directory 'duckdb'
#   warning: no files found matching '*.h' under directory 'src'
#   warning: manifest_maker: MANIFEST.in, line 6: 'recursive-include' expects <dir> <pattern1> <pattern2> ...
#
#   writing manifest file 'duckdb.egg-info\SOURCES.txt'
#   creating build\lib.win32-cpython-39\duckdb-stubs
#   copying duckdb-stubs\__init__.pyi -> build\lib.win32-cpython-39\duckdb-stubs
#   creating build\lib.win32-cpython-39\duckdb-stubs\functional
#   copying duckdb-stubs\functional\__init__.pyi -> build\lib.win32-cpython-39\duckdb-stubs\functional
#   creating build\lib.win32-cpython-39\duckdb-stubs\typing
#   copying duckdb-stubs\typing\__init__.pyi -> build\lib.win32-cpython-39\duckdb-stubs\typing
#   creating build\lib.win32-cpython-39\duckdb-stubs\value
#   copying duckdb-stubs\value\__init__.pyi -> build\lib.win32-cpython-39\duckdb-stubs\value
#   creating build\lib.win32-cpython-39\duckdb-stubs\value\constant
#   copying duckdb-stubs\value\constant\__init__.pyi -> build\lib.win32-cpython-39\duckdb-stubs\value\constant
#   copying duckdb\experimental\spark\LICENSE -> build\lib.win32-cpython-39\duckdb\experimental\spark
#   running build_ext
#   building 'duckdb.duckdb' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for duckdb
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\himanchal.a.singh\Anaconda3\python.exe' 'C:\Users\himanchal.a.singh\Anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\HIMANC~1.SIN\AppData\Local\Temp\tmpr6lptbva'
#        cwd: C:\Users\himanchal.a.singh\AppData\Local\Temp\pip-install-t81v27_x\hnswlib_e6b58cfc07164a299021c6e4248ef7d1
#   Complete output (5 lines):
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'hnswlib' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for hnswlib
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\himanchal.a.singh\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\himanchal.a.singh\\AppData\\Local\\Temp\\pip-install-t81v27_x\\httptools_b0fdc8aefa88462c96cda160e6f2e7a1\\setup.py'"'"'; __file__='"'"'C:\\Users\\himanchal.a.singh\\AppData\\Local\\Temp\\pip-install-t81v27_x\\httptools_b0fdc8aefa88462c96cda160e6f2e7a1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\himanchal.a.singh\AppData\Local\Temp\pip-wheel-tpwox1t3'
#        cwd: C:\Users\himanchal.a.singh\AppData\Local\Temp\pip-install-t81v27_x\httptools_b0fdc8aefa88462c96cda160e6f2e7a1\
#   Complete output (23 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win32-3.9
#   creating build\lib.win32-3.9\httptools
#   copying httptools\_version.py -> build\lib.win32-3.9\httptools
#   copying httptools\__init__.py -> build\lib.win32-3.9\httptools
#   creating build\lib.win32-3.9\httptools\parser
#   copying httptools\parser\errors.py -> build\lib.win32-3.9\httptools\parser
#   copying httptools\parser\__init__.py -> build\lib.win32-3.9\httptools\parser
#   running egg_info
#   writing httptools.egg-info\PKG-INFO
#   writing dependency_links to httptools.egg-info\dependency_links.txt
#   writing requirements to httptools.egg-info\requires.txt
#   writing top-level names to httptools.egg-info\top_level.txt
#   reading manifest file 'httptools.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file 'httptools.egg-info\SOURCES.txt'
#   running build_ext
#   building 'httptools.parser.parser' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for httptools
# ERROR: Could not build wheels for duckdb, hnswlib which use PEP 517 and cannot be installed directly
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# Requirement already satisfied: numpy in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from sentence-transformers) (1.21.5)
# Requirement already satisfied: tqdm in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from sentence-transformers) (4.64.0)
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#   Downloading sentence_transformers-2.6.0-py3-none-any.whl (163 kB)
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#   Downloading sentence_transformers-2.5.0-py3-none-any.whl (156 kB)
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp39-cp39-win32.whl (936 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.0-py3-none-any.whl (132 kB)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from sentence-transformers) (4.40.0)
#   Downloading sentence-transformers-2.2.1.tar.gz (84 kB)
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
# Requirement already satisfied: tokenizers>=0.10.3 in c:\users\himanchal.a.singh\anaconda3\lib\site-packages (from sentence-transformers) (0.19.1)
#   Downloading sentence-transformers-2.0.0.tar.gz (85 kB)
#   Downloading sentence-transformers-1.2.1.tar.gz (80 kB)
#   Downloading sentence-transformers-1.2.0.tar.gz (81 kB)
#   Downloading sentence-transformers-1.1.1.tar.gz (81 kB)
#   Downloading sentence-transformers-1.1.0.tar.gz (78 kB)
#   Downloading sentence-transformers-1.0.4.tar.gz (74 kB)
#   Downloading sentence-transformers-1.0.3.tar.gz (74 kB)
#   Downloading sentence-transformers-1.0.2.tar.gz (74 kB)
#   Downloading sentence-transformers-1.0.1.tar.gz (74 kB)
#   Downloading sentence-transformers-1.0.0.tar.gz (74 kB)
#   Downloading sentence-transformers-0.4.1.2.tar.gz (64 kB)
#   Downloading sentence-transformers-0.4.1.1.tar.gz (64 kB)
#   Downloading sentence-transformers-0.4.1.tar.gz (64 kB)
#   Downloading sentence-transformers-0.4.0.tar.gz (65 kB)
#   Downloading sentence-transformers-0.3.9.tar.gz (64 kB)
# Collecting transformers<3.6.0,>=3.1.0
#   Downloading transformers-3.5.1-py3-none-any.whl (1.3 MB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.3.8.tar.gz (66 kB)
# Collecting transformers<3.4.0,>=3.1.0
#   Downloading transformers-3.3.1-py3-none-any.whl (1.1 MB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.3.7.2.tar.gz (59 kB)
#   Downloading sentence-transformers-0.3.7.1.tar.gz (59 kB)
#   Downloading sentence-transformers-0.3.7.tar.gz (59 kB)
#   Downloading sentence-transformers-0.3.6.tar.gz (62 kB)
# Collecting transformers<3.2.0,>=3.1.0
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.3.5.1.tar.gz (61 kB)
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.3.5.tar.gz (61 kB)
#   Downloading sentence-transformers-0.3.4.tar.gz (61 kB)
#   Downloading sentence-transformers-0.3.3.tar.gz (65 kB)
#   Downloading sentence-transformers-0.3.2.tar.gz (65 kB)
#   Downloading sentence-transformers-0.3.1.tar.gz (64 kB)
#   Downloading sentence-transformers-0.3.0.tar.gz (61 kB)
#   Downloading sentence-transformers-0.2.6.2.tar.gz (60 kB)
# Collecting transformers==2.11.0
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.2.6.1.tar.gz (55 kB)
#   Downloading sentence-transformers-0.2.5.1.tar.gz (52 kB)
# Collecting transformers==2.3.0
#   Downloading transformers-2.3.0-py3-none-any.whl (447 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.2.5.tar.gz (49 kB)
#   Downloading sentence-transformers-0.2.4.1.tar.gz (49 kB)
# Collecting transformers==2.2.1
#   Downloading transformers-2.2.1-py3-none-any.whl (364 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.2.4.tar.gz (49 kB)
#   Downloading sentence-transformers-0.2.3.tar.gz (45 kB)
# Collecting pytorch-transformers==1.1.0
#   Downloading pytorch_transformers-1.1.0-py3-none-any.whl (158 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.2.2.tar.gz (44 kB)
#   Downloading sentence-transformers-0.2.1.tar.gz (42 kB)
# Collecting pytorch-transformers==1.0.0
#   Downloading pytorch_transformers-1.0.0-py3-none-any.whl (137 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-0.2.0.tar.gz (28 kB)
#   Downloading sentence-transformers-0.1.0.tar.gz (35 kB)
#
# The conflict is caused by:
#     sentence-transformers 2.7.0 depends on torch>=1.11.0
#     sentence-transformers 2.6.1 depends on torch>=1.11.0
#     sentence-transformers 2.6.0 depends on torch>=1.11.0
#     sentence-transformers 2.5.1 depends on torch>=1.11.0
#     sentence-transformers 2.5.0 depends on torch>=1.11.0
#     sentence-transformers 2.4.0 depends on torch>=1.11.0
#     sentence-transformers 2.3.1 depends on torch>=1.11.0
#     sentence-transformers 2.3.0 depends on torch>=1.11.0
#     sentence-transformers 2.2.2 depends on torch>=1.6.0
#     sentence-transformers 2.2.1 depends on torch>=1.6.0
#     sentence-transformers 2.2.0 depends on torch>=1.6.0
#     sentence-transformers 2.1.0 depends on torch>=1.6.0
# ERROR: Cannot install sentence-transformers==0.1.0, sentence-transformers==0.2.0, sentence-transformers==0.2.1, sentence-transformers==0.2.2, sentence-transformers==0.2.3, sentence-transformers==0.2.4, sentence-transformers==0.2.4.1, sentence-transformers==0.2.5, sentence-transformers==0.2.5.1, sentence-transformers==0.2.6.1, sentence-transformers==0.2.6.2, sentence-transformers==0.3.0, sentence-transformers==0.3.1, sentence-transformers==0.3.2, sentence-transformers==0.3.3, sentence-transformers==0.3.4, sentence-transformers==0.3.5, sentence-transformers==0.3.5.1, sentence-transformers==0.3.6, sentence-transformers==0.3.7, sentence-transformers==0.3.7.1, sentence-transformers==0.3.7.2, sentence-transformers==0.3.8, sentence-transformers==0.3.9, sentence-transformers==0.4.0, sentence-transformers==0.4.1, sentence-transformers==0.4.1.1, sentence-transformers==0.4.1.2, sentence-transformers==1.0.0, sentence-transformers==1.0.1, sentence-transformers==1.0.2, sentence-transformers==1.0.3, sentence-transformers==1.0.4, sentence-transformers==1.1.0, sentence-transformers==1.1.1, sentence-transformers==1.2.0, sentence-transformers==1.2.1, sentence-transformers==2.0.0, sentence-transformers==2.1.0, sentence-transformers==2.2.0, sentence-transformers==2.2.1, sentence-transformers==2.2.2, sentence-transformers==2.3.0, sentence-transformers==2.3.1, sentence-transformers==2.4.0, sentence-transformers==2.5.0, sentence-transformers==2.5.1, sentence-transformers==2.6.0, sentence-transformers==2.6.1 and sentence-transformers==2.7.0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies
#     sentence-transformers 2.0.0 depends on torch>=1.6.0
#     sentence-transformers 1.2.1 depends on torch>=1.6.0
#     sentence-transformers 1.2.0 depends on torch>=1.6.0
#     sentence-transformers 1.1.1 depends on torch>=1.6.0
#     sentence-transformers 1.1.0 depends on torch>=1.6.0
#     sentence-transformers 1.0.4 depends on torch>=1.6.0
#     sentence-transformers 1.0.3 depends on torch>=1.6.0
#     sentence-transformers 1.0.2 depends on torch>=1.6.0
#     sentence-transformers 1.0.1 depends on torch>=1.6.0
#     sentence-transformers 1.0.0 depends on torch>=1.6.0
#     sentence-transformers 0.4.1.2 depends on torch>=1.6.0
#     sentence-transformers 0.4.1.1 depends on torch>=1.6.0
#     sentence-transformers 0.4.1 depends on torch>=1.6.0
#     sentence-transformers 0.4.0 depends on torch>=1.6.0
#     sentence-transformers 0.3.9 depends on torch>=1.6.0
#     sentence-transformers 0.3.8 depends on torch>=1.2.0
#     sentence-transformers 0.3.7.2 depends on torch>=1.2.0
#     sentence-transformers 0.3.7.1 depends on torch>=1.2.0
#     sentence-transformers 0.3.7 depends on torch>=1.2.0
#     sentence-transformers 0.3.6 depends on torch>=1.2.0
#     sentence-transformers 0.3.5.1 depends on torch>=1.2.0
#     sentence-transformers 0.3.5 depends on torch>=1.2.0
#     sentence-transformers 0.3.4 depends on torch>=1.2.0
#     sentence-transformers 0.3.3 depends on torch>=1.2.0
#     sentence-transformers 0.3.2 depends on torch>=1.2.0
#     sentence-transformers 0.3.1 depends on torch>=1.2.0
#     sentence-transformers 0.3.0 depends on torch>=1.0.1
#     sentence-transformers 0.2.6.2 depends on torch>=1.0.1
#     sentence-transformers 0.2.6.1 depends on torch>=1.0.1
#     sentence-transformers 0.2.5.1 depends on torch>=1.0.1
#     sentence-transformers 0.2.5 depends on torch>=1.0.1
#     sentence-transformers 0.2.4.1 depends on torch>=1.0.1
#     sentence-transformers 0.2.4 depends on torch>=1.0.1
#     sentence-transformers 0.2.3 depends on torch>=1.0.1
#     sentence-transformers 0.2.2 depends on torch>=1.0.1
#     sentence-transformers 0.2.1 depends on torch>=1.0.1
#     sentence-transformers 0.2.0 depends on torch>=1.0.1
#     sentence-transformers 0.1.0 depends on torch>=1.0.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict

# %%
# Import necessary libraries for Preprocessing the data.

import json
import ast
import re
import pandas as pd

# %% [markdown]
# # **A. Preprcessing data**
#
# This dataset comprises multiple columns representing data from diverse sources such as email, SMS, API, etc. Among these, we have **selected "annotations" as our metadata, "comments" to analyze the conversation between visitors and agents, and "ticket_id" as the unique identifier for our conversations**.
#
# We have done the following steps to clean our data
#
# 1. The "theme" key was removed from annotations due to its consistently empty values across all entries.
# 2. All topics and aspects were consolidated into a single list, and the maximum sentiment score was converted into a string.
# 3. The content from both the Visitor and Agent keys in the comments was extracted and labeled as user and agent Q&A. **(It's worth noting that for content originating from APIs, the body part was omitted due to frequent redundancy.)**

# %%
# Define the DataProcessor class. This class handles data loading, processing, and annotation manipulation.

class DataProcessor:
    def __init__(self, file_path):
        self.file_path = file_path
        self.df = None
        self.load_data()

    def load_data(self):
        """Load the CSV file into a DataFrame."""
        self.df = pd.read_csv(self.file_path)

    def remove_theme_key(self):
        annotations_column = self.df['annotations']
        for i, annotations_str in annotations_column.items():
            try:
                annotations_list = json.loads(annotations_str.strip(" ' "))
                for annotation in annotations_list:
                    annotation.pop('theme', None)
                annotations_column.at[i] = str(annotations_list)
            except json.JSONDecodeError:
                continue

    def aggregate_annotation_data_corrected(self):
        annotations_column = self.df['annotations']
        aggregated_data = []
        for annotations_str in annotations_column:
            try:
                annotations_str_cleaned = annotations_str.replace("'", "\"")
                topics, topic_aspects, sentiments = [], [], []
                annotations_list = json.loads(annotations_str_cleaned)
                for annotation in annotations_list:
                    if 'topic' in annotation:
                        topics.append(annotation['topic'])
                    if 'topicAspects' in annotation:
                        topic_aspects.extend([aspect for aspect in annotation['topicAspects'] if aspect not in topic_aspects])
                    if 'sentiment' in annotation:
                        sentiments.append(annotation['sentiment'])
                aggregated_data.append({
                    'topics': topics,
                    'topicAspects': topic_aspects,
                    'sentiments': None if not sentiments else max(set(sentiments), key=sentiments.count)
                })
            except json.JSONDecodeError:
                aggregated_data.append({'topics': [], 'topicAspects': [], 'sentiments': []})
        self.df['annotations'] = aggregated_data

    def process_comments(self):
        self.df['processed_comments'] = self.df.apply(lambda x: self._process_comment_entry(x['comments'], x['metadata.channel']), axis=1)

    def _process_comment_entry(self, comments_str, metadata_channel):
        processed_comments = []
        try:
            comments_list = json.loads(comments_str.strip("'"))
            for entry in comments_list:
                author_type = entry.get('authorType', '').lower()
                body = entry.get('body', '')
                if metadata_channel == 'api' and author_type == 'visitor':
                    match = re.search(r'message(.*?)initialurl', body, re.IGNORECASE)
                    if match:
                        body = match.group(1).strip()
                if author_type == 'visitor':
                    processed_comments.append({'user': body})
                elif author_type == 'agent':
                    processed_comments.append({'agent': body})
        except json.JSONDecodeError:
            pass
        return processed_comments

    def get_processed_data(self):
        """Return the processed DataFrame."""
        return self.df

    def process(self):
        self.remove_theme_key()
        self.aggregate_annotation_data_corrected()
        self.process_comments()

# %% [markdown]
# # **B. Filter Conversations and Metadata**
#
#   Here we parse data in the respective format-- **{
#       "conversation_id": "123",
#       "interactions": [
#           {"user": "User question"},
#           {"agent": "Agent follow-up answer"},
#           {"agent": "User question"},
#           {"agent": "Agent follow-up answer"},
#           // ... more interactions
#       ],
#       "metadata": {
#           "topics": ["x", "y"],
#           "topic_aspects": ["a", "b"],
#           "sentiment": 1
#       }
#   }**
#
#   To format the lists of final_test, final_id, and final_metadata compatible with Vector DB, we need to ensure that each entry is structured appropriately for storage. Vector DB typically requires a structured format such as JSON.
#
#   **Note:- here we are using two special tokens USER_TOKEN and AGENT_TOKEN to be encapsulated befor the user question or the agent's answer , so that our model can distinct between the two.**

# %%
class ConversationProcessor:
    USER_TOKEN = "<USER>"
    AGENT_TOKEN = "<AGENT>"

    def __init__(self, final_data):
        self.file_path = file_path
        self.conversations = []
        self.final_text = []
        self.final_id = []
        self.final_metadata = []
        self.converted_metadata = []

    def process_data(self):
        self.construct_conversations()
        self.process_conversations()
        self.convert_metadata()

    def construct_conversations(self):
        for index, row in final_data.iterrows():
            conversation = {
                "conversation_id": str(row["_id"]),
                "interactions": ast.literal_eval(str(row["processed_comments"])),
                # "interactions": json.loads((row["processed_comments"]).replace("'")),
                "metadata": ast.literal_eval(str(row["annotations"]))
            }
            self.conversations.append(conversation)

    def clean_text(self, text):
        cleaned_text = re.sub(r"[^a-zA-Z0-9\s" + re.escape(self.USER_TOKEN + self.AGENT_TOKEN) + "]", "", text)
        return cleaned_text.strip()

    def process_conversations(self):
        for conversation in self.conversations:
            conversation_text = ""
            for turn in conversation["interactions"]:
                if 'user' in turn:
                    user_text = self.clean_text(turn['user'])
                    conversation_text += f"{self.USER_TOKEN} {user_text} "
                if 'agent' in turn:
                    agent_text = self.clean_text(turn['agent'])
                    conversation_text += f"{self.AGENT_TOKEN} {agent_text} "

            self.final_id.append(conversation['conversation_id'])
            self.final_text.append(conversation_text)
            self.final_metadata.append(conversation['metadata'])

    def value_to_string(self, value):
        if isinstance(value, list):
            return ' '.join(map(str, value))
        return str(value)

    def convert_metadata(self):
        for item in self.final_metadata:
            converted_item = {k: self.value_to_string(v) for k, v in item.items()}
            self.converted_metadata.append(converted_item)

# %% [markdown]
# # **C. Load data**
#
# Using above two Classes and its attributes, we parse our data by give the CSV file path

# %%
import os

# Get the file path from the environment variable
file_path = os.getenv('ASSESSMENT_CSV_PATH')

# Check if the environment variable is set and the file path is valid
if file_path:
    print("File path retrieved from environment variable:", file_path)
else:
    print("Environment variable ASSESSMENT_CSV_PATH is not set.")


processor = DataProcessor(file_path)
processor.process()
final_data = processor.get_processed_data()
# Out:
# File path retrieved from environment variable: /content/assesment.csv

# %%
# Usage
Conversations= ConversationProcessor(final_data)
Conversations.process_data()
# Now you can access the processed data
print(Conversations.final_text[:3])  # Print first few entries of the processed text
print(Conversations.converted_metadata[:3])  # Print first few entries of the converted metadata
# Out:
# ['<USER> Hi I received my order today and only received a two month supply that included a bottle with a bag of refill Joshua Lili ', '<USER> Please follow up with the customer about the feedback they provided Star rating 1 Comment Terrible customer service I would not be going out of my way to leave this message if it was not that awful Original ticket REDACTED <AGENT> This request was closed and merged into request 1566318 New ticket from dacquaah21gmail ', '<USER> Hi How do I add the DHT blocker to my order <USER> Mens Hairline Defender 3 Month Mens Hairline Defender 3 Month Hair Growth REDACTEDceutical Remove 330 280 ']
# [{'topics': 'missing item', 'topicAspects': 'refill joshua lili order today', 'sentiments': '2'}, {'topics': 'support responsiveness customer support feedback', 'topicAspects': 'provided star rating comment terrible customer awful original ticket', 'sentiments': '1'}, {'topics': 'amend order', 'topicAspects': 'order add the dht dht blocker', 'sentiments': '2'}]

# %% [markdown]
# # **D. Data Indexing and Querying**
#
# 1. **Vector Database:** Using **ChromaDB** from the Langchain community open-source vector database. ChromaDB provides capabilities for storing and querying vector embeddings efficiently.
#
# 2. **Embedding Model:** Opted for the **HuggingFaceEmbeddings-all-mpnet-base-v2 model**, which is based on the Sentence Transformers base model. This model allows you to generate embeddings for sentences or text passages. Since our chats consist of multiple sentences separated by special tokens, using a sentence transformer-based model is suitable for preserving the structure of our conversations.
#
# 3. **Embedding Generation:** Used the chosen model (HuggingFaceEmbeddings-all-mpnet-base-v2) to generate embeddings for each sentence in our chat conversations.
#
# 4. **Data Storage:** Store the generated embeddings along with the associated metadata (such as chat IDs,annotations, etc.) in ChromaDB.
#
# 5. **Querying and Retrieval:** Implement mechanisms to query ChromaDB for retrieving embeddings based on queries
#
# With this setup,I efficiently stored and retrieved embeddings for our chat conversations using ChromaDB and the chosen embedding model.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig,pipeline
from transformers import BitsAndBytesConfig
from langchain.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
import torch

# %%
# Initialize a new Hugging Face embeddings model using the specified model_name ("all-mpnet-base-v2")
new_embedding = HuggingFaceEmbeddings(model_name="all-mpnet-base-v2")

# Create a Chroma instance and index texts, embeddings, metadata, and IDs into the database
vectordb = Chroma.from_texts(
    texts=Conversations.final_text,  # Texts to be indexed
    embedding=new_embedding,  # Embeddings to be indexed
    metadatas=Conversations.converted_metadata,  # Metadata associated with the texts
    ids=Conversations.final_id,  # IDs associated with the texts
    collection_name="rag_application"  # Name of the collection in the database
)

# Convert the indexed database into a retriever for search purposes, specifying search parameters
retriever = vectordb.as_retriever(search_kwargs={"k": 5})

# Retrieve relevant documents based on the query "How can i get refund?"
docs = retriever.get_relevant_documents("How can i get refund?")

# Calculate the number of relevant documents retrieved
len(docs)
# Out:
# 5

# %% [markdown]
# # **E. Quantized LLM**
#
#
# 1. **Model and Tokenizer:** The code initializes a tokenizer using the pretrained model name 'mistralai/Mistral-7B-Instruct-v0.1'. Mistral-7B-Instruct prioritizes accuracy and context-awareness. Its use of rolling buffer caching efficiently retains relevant information across sequences
#
# 2. **Efficient Model Loading:** By utilizing 4-bit precision base model loading (use_4bit=True), the code optimizes memory usage during model loading. it reduces the memory footprint and accelerates loading times.
#
# 3. **Quantization for Reduced Precision:** The code implements quantization techniques such as "nf4" (nearest float 4-bit) to reduce the precision of model parameters and computations. This reduction in precision helps conserve memory and computation resources.

# %%
from langchain.prompts import PromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.llms import HuggingFacePipeline
from langchain.chains import LLMChain

# %%
model_name='mistralai/Mistral-7B-Instruct-v0.1'


tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

#################################################################
# bitsandbytes parameters
#################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

#################################################################
# Set up quantization config
#################################################################
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

#################################################################
# Load pre-trained config
#################################################################
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# # **F.Pipeline**
#
# **Here we use the Hugging Face pipeline in our code for streamlining the approach to integrate our model, tokenizer, and configurable parameters into a cohesive workflow.**

# %%
text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    temperature=0.0,
    # repetition_penalty=1.1,
    return_full_text=True,
    max_new_tokens=1000,
)

mistral_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %% [markdown]
# # **G.Templates**
#
#
# The provided code defines multiple prompt templates aimed at enhancing the efficiency of your model. Here's a breakdown of each template:
#
# 1. **Template 1:**
# Instructs to answer truthfully using provided context.
#
# 2. **Template 2**:
# Answer question using provided context. If context is insufficient, respond accordingly.
#
# 3. **Template 3:**
# Answer question using provided context. If context is insufficient, respond accordingly. Avoid sharing personal details.
#
# 4. **Template 4:**
# Answer question using context. If context is insufficient, respond accordingly. Avoid personal details and specified restricted topics.
#
# 5. **Template 5:**
# Answer question using context. If context is insufficient, respond accordingly. Avoid personal details and specified restricted topics (marked as urgent).
#
#
# **Note:**- These templates helps us in providing features like
#
# 1. **Removing personal Information**
#
# 2. **Answers only on the Available data**
#
# 3. **Ban specific phrases/ restricted topics to generate query**

# %%
# Define your list of restricted topics
restricted_topics_list = ["refund", "subscription"]
formatted_restricted_topics = ", ".join(restricted_topics_list)

# Template1
prompt_template1 = """
### [INST] Instruction: "Answer the question as truthfully as possible using the provided context, and if the answer is not contained within the context and requires some latest information to be updated, print 'Sorry Not Sufficient context to answer query'":

{context}

### QUESTION:
{question} [/INST]
"""

# Template2
prompt_template2 = """
### [INST] Instruction:
Answer the question below using the provided context. If the context contains relevant information to answer the question, use that information to provide a response. If the context does not contain the necessary information or is insufficient to form a complete answer, respond with 'Sorry, not sufficient context to answer this query.'

### CONTEXT:
{context}

### QUESTION:
{question}

### ANSWER:
"""

# Template3
prompt_template3 = """
### [INST] Instruction:
Answer the question below using the provided context. If the context contains relevant information to answer the question, use that information to provide a response. If the context does not contain the necessary information or is insufficient to form a complete answer, respond with 'Sorry, not sufficient context to answer this query.' Do not share any specific personal details such as names, addresses, or email addresses in your response.

### CONTEXT:
{context}

### QUESTION:
{question}

### ANSWER:
"""

# Template4
prompt_template4 = f"""
### [INST] Instruction:
Answer the question below using the provided context. If the context contains relevant information to answer the question, use that information to provide a response. If the context does not contain the necessary information or is insufficient to form a complete answer, respond with 'Sorry, not sufficient context to answer this query.' Do not share any specific personal details such as names, addresses, or email addresses. Additionally, avoid discussing the following topics: {formatted_restricted_topics}.

### CONTEXT:
{{context}}

### QUESTION:
{{question}}

### ANSWER:
"""

# Template5
prompt_template5 = f"""
### [URGENT INSTRUCTION]
Do not discuss any of the following topics in your response: {formatted_restricted_topics}. This is a critical requirement.

### [INST] Instruction:
Answer the question below using the provided context. If the context does not contain the necessary information or is insufficient to form a complete answer, respond with 'Sorry, not sufficient context to answer this query.' Do not share any specific personal details such as names, addresses, or email addresses.

### CONTEXT:
{{context}}

### QUESTION:
{{question}}

### ANSWER:
"""

# %% [markdown]
# # **H. LLM Chain**
#
#
# **Here we used the LLM chain architecture allowing for easy integration of various components such as retrievers, prompts, and language models.
# Here Prompts provide structured input to the language model, guiding the generation of coherent and contextually relevant responses**

# %%
# Define the prompt template using PromptTemplate
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template3,  # Specify the prompt template to use
)

# Initialize the LLMChain with the specified language model (mistral_llm) and prompt template
llm_chain = LLMChain(llm=mistral_llm, prompt=prompt)

# Define the RAG (Retriever-Generator) chain using a pipeline of components
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}  # Define the input variables and their sources
    | llm_chain  # Connect the retriever and language model chain
)

# Invoke the RAG chain with a sample question ("How can we cancel our subscription?")
rag_chain.invoke("How can we cancel our subscription?")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# {'context': [Document(page_content='<USER> Cancel subscription Hello How can I cancel my subscription ', metadata={'sentiments': '1', 'topicAspects': 'gee email michellegeehomesgmailcom chrome browser version email michellegeehomesgmailcom gatsbytoken michelle gee email cancel subscription single email michellegeehomesgmailcom phone', 'topics': 'cancel subscription switch to/from vegan'}),
#   Document(page_content='<USER> I want to cancel my subscription and need help to do so Hello I do not see a place where I can cancel How do I cancel the subscription manually <AGENT> Hi Catherine Thank you for reaching out Were happy to help with your inquiry It looks like you found your way around our website and canceled your subscription online and we are confirming your cancellation now  If you change your mind down the road you can reactivate this subscription by logging into your account or requesting we restart it for you Please dont hesitate to reach out with any further questions or concerns  were always happy to help Have a great day  Yasmine K Customer Experience Specialist Keep Growing ', metadata={'sentiments': '1', 'topicAspects': 'device macos introshown catherine steel email email cmsteelverizonnet phone steel email cmsteelverizonnet macintosh intel mac cancel subscription single', 'topics': 'cancel subscription'}),
#   Document(page_content='<USER> How do I cancel my subscription <AGENT> Hi Veronica Your subscription has been canceled so you will not be charged unless you place a new order If you change your mind down the road you can reactivate this subscription by logging into your account or requesting we restart it for you Please let us know if you need any further assistance  Dominique K Lead Customer Experience Specialist Keep Growing ', metadata={'sentiments': '1', 'topicAspects': 'cancel my subscription', 'topics': 'cancel subscription'}),
#   Document(page_content='<USER> Hello My name is Madison I would like to know how to cancel my subscription Please let me know asap Thank you Madison Brizida <AGENT> Hi Madison Thank you for reaching out Were happy to help with your inquiry It looks like you found your way around our website and canceled your subscription online and we are confirming your cancellation now  If you change your mind down the road you can reactivate this subscription by logging into your account or requesting we restart it for you Would you mind letting us know a bit more about why youre canceling today We want to make sure youre getting the most out of your subscription and we appreciate any feedback we can get Let me know if I can help with anything else in the meantime Were looking forward to your reply  Leyna M Customer Experience Agent Keep Growing ', metadata={'sentiments': '2', 'topicAspects': 'cancel my subscription madison brizida', 'topics': 'cancel subscription'}),
#   Document(page_content='<USER> Can you please tell me how to cancel my subscription Thank you Tara Gostovich <AGENT> Hi Tara Thank you for reaching out Were happy to help with your inquiry Your subscription has been canceled so you will not be charged unless you place a new order If you change your mind down the road you can reactivate this subscription by logging into your account or requesting we restart it for you Please note this does not cancel your June 18th order which is in transit and is expected to arrive on June 21st Tracking Let me know if youd like me to send return instructions Let me know if I can help with anything else for now Have a great rest of the day  Kershee H Customer Experience Agent Keep Growing ', metadata={'sentiments': '1', 'topicAspects': 'cancel my subscription', 'topics': 'cancel subscription'})],
#  'question': 'How can we cancel our subscription?',
#  'text': '\nTo cancel your subscription, you can log into your account or request that it be restarted for you. If you change your mind down the road, you can reactivate your subscription by logging into your account or requesting that it be restarted for you.'}

# %%
torch.cuda.empty_cache()

# %% [markdown]
# # **I. Chat Interface**
#
#
# **Using Gradio to create a chat interface:**
#
#  It offers a user-friendly and versatile framework for building chat interfaces that are interactive, customizable, and seamlessly integrated with our models used for conversational agents.

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !pip install gradio==3.48.0

# %%
import gradio as gr

# Define the function to handle user inputs and return responses
def chatbot_interface(user_input):
    response = rag_chain.invoke(user_input)
    answer = response['text']
    return answer

# Create the Gradio interface
iface = gr.Interface(
    fn=chatbot_interface,
    inputs=gr.Textbox(),
    outputs=gr.Textbox(),
    capture_session=True  # This is to capture the CUDA sessions if you are using GPU
)

# Add a button to trigger the chatbot response
iface.launch(share=True)
# Out:
# <ipython-input-19-4a1e5ab9c8f6>:10: GradioDeprecationWarning: `capture_session` parameter is deprecated, and it has no effect
#   iface = gr.Interface(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://7dda5ff4110a688c2f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7dda5ff4110a688c2f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # **Examples**

# %% [markdown]
# <img src='https://drive.google.com/uc?id=121vv-cWwPPyqcd9UIFTTu7WM8bfgdpvC'>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1Yfi6Vd44Iqfy4FeRTjgOcG6UYFwOXwyA'>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1uVV_AfwQC5wIi89cVlXTrMvv6VcfPsLN'>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=12wBAYhz8jyBcmRyD6qEYqsXnWpcL-Tno'>
